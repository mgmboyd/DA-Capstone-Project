# %% [markdown]
# <a href="https://colab.research.google.com/github/mgmboyd/DA-Capstone-Project/blob/master/MGB_DA_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CAPSTONE PROJECT**

# %% [markdown]
# # **DATA BACKGROUND**
#
# * datasource link: https://github.com/mgmboyd/DA-Capstone-Project/blob/master/
#
# * datafile link: https://raw.githubusercontent.com/mgmboyd/DA-Capstone-Project/master/No%20Show%20-%20FY20%20FINAL%20DATA%20SET%20-%20FINAL%20CSV.csv

# %% [markdown]
# # **DATA GATHERING**

# %%
# LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
import plotly.express as px
import seaborn as sns
sns.set()
# !pip install sodapy
# Out:
# Requirement already satisfied: sodapy in /usr/local/lib/python3.6/dist-packages (2.1.0)
# Requirement already satisfied: requests>=2.20.0 in /usr/local/lib/python3.6/dist-packages (from sodapy) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->sodapy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->sodapy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.20.0->sodapy) (2020.6.20)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mgmboyd/DA-Capstone-Project/master/No%20Show%20-%20FY20%20FINAL%20DATA%20SET%20-%20FINAL%20CSV.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21226 entries, 0 to 21225
# Data columns (total 50 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   mrn                     21225 non-null  float64
#  1   dob                     21225 non-null  object
#  2   age                     21225 non-null  float64
#  3   sex                     21225 non-null  object
#  4   phone                   21022 non-null  object
#  5   encounter_provider      21225 non-null  object
#  6   visit_date              21225 non-null  object
#  7   appt_time               21225 non-null  object
#  8   month                   21225 non-null  object
#  9   day_of_the_week         21225 non-null  object
#  10  holiday                 21225 non-null  object
#  11  weather_type            21225 non-null  object
#  12  max_temp                21225 non-null  float64
#  13  mini_temp               21225 non-null  float64
#  14  avg_temp                21225 non-null  float64
#  15  departure               21225 non-null  float64
#  16  hdd                     21225 non-null  float64
#  17  cdd                     21225 non-null  float64
#  18  precipitation           21225 non-null  float64
#  19  new_snow                21225 non-null  float64
#  20  snow_depth              21225 non-null  float64
#  21  status                  21225 non-null  object
#  22  encounter_closed        899 non-null    object
#  23  dept                    21225 non-null  object
#  24  dept_id                 21225 non-null  float64
#  25  Avg_payment             21225 non-null  float64
#  26  visit_type              21225 non-null  object
#  27  visit_type_id           21225 non-null  float64
#  28  copay_paid              883 non-null    float64
#  29  chkin_time              549 non-null    object
#  30  check_in-check out      21220 non-null  object
#  31  encounter_diagnoses     517 non-null    object
#  32  next_appt               11870 non-null  object
#  33  appt_type               21225 non-null  object
#  34  patient_employer        7083 non-null   object
#  35  employer_state          284 non-null    object
#  36  patient_state           21225 non-null  object
#  37  time_with_provider      75 non-null     object
#  38  wait_time_for_provider  135 non-null    object
#  39  zip_code                21225 non-null  object
#  40  pcp                     19766 non-null  object
#  41  reason_for_visit        274 non-null    object
#  42  roomed_time             153 non-null    object
#  43  employer_zip            21225 non-null  object
#  44  attending_provider      1175 non-null   object
#  45  service                 6134 non-null   object
#  46  language                21162 non-null  object
#  47  religion                21146 non-null  object
#  48  hosp_acct               21225 non-null  object
#  49  special_needs           859 non-null    object
# dtypes: float64(15), object(35)
# memory usage: 8.1+ MB

# %%
df.shape
# Out:
# (21226, 50)

# %%
df.head()
# Out:
#        mrn         dob   age  ...  religion  hosp_acct special_needs
# 0  10302.0  10/10/1965  54.0  ...    Muslim     <NONE>           NaN
# 1   8542.0  05/04/1970  50.0  ...  Catholic     <NONE>           NaN
# 2  12208.0  10/23/1961  58.0  ...   Unknown     <NONE>           NaN
# 3  21117.0  05/21/1949  70.0  ...   Baptist  251001017           NaN
# 4  18461.0  02/24/1948  72.0  ...   Unknown  251003614           NaN
#
# [5 rows x 50 columns]

# %%
df.tail()
# Out:
#            mrn         dob   age  ...     religion  hosp_acct special_needs
# 21221  10301.0  08/08/1967  53.0  ...  Pentecostal  251907478          None
# 21222  17796.0  12/12/1950  69.0  ...      Unknown  251901977           NaN
# 21223  16786.0  08/02/1954  66.0  ...      Unknown     <NONE>           NaN
# 21224   3993.0  01/10/1987  33.0  ...    Christian     <NONE>           NaN
# 21225      NaN         NaN   NaN  ...          NaN        NaN           NaN
#
# [5 rows x 50 columns]

# %%
df.drop(df.index[21225])
# Out:
#            mrn         dob   age  ...     religion  hosp_acct special_needs
# 0      10302.0  10/10/1965  54.0  ...       Muslim     <NONE>           NaN
# 1       8542.0  05/04/1970  50.0  ...     Catholic     <NONE>           NaN
# 2      12208.0  10/23/1961  58.0  ...      Unknown     <NONE>           NaN
# 3      21117.0  05/21/1949  70.0  ...      Baptist  251001017           NaN
# 4      18461.0  02/24/1948  72.0  ...      Unknown  251003614           NaN
# ...        ...         ...   ...  ...          ...        ...           ...
# 21220   9838.0  11/25/1967  52.0  ...      Unknown  251907518           NaN
# 21221  10301.0  08/08/1967  53.0  ...  Pentecostal  251907478          None
# 21222  17796.0  12/12/1950  69.0  ...      Unknown  251901977           NaN
# 21223  16786.0  08/02/1954  66.0  ...      Unknown     <NONE>           NaN
# 21224   3993.0  01/10/1987  33.0  ...    Christian     <NONE>           NaN
#
# [21225 rows x 50 columns]

# %%
df.columns
# Out:
# Index(['mrn', 'dob', 'age', 'sex', 'phone', 'encounter_provider', 'visit_date',
#        'appt_time', 'month', 'day_of_the_week', 'holiday', 'weather_type',
#        'max_temp', 'mini_temp', 'avg_temp', 'departure', 'hdd', 'cdd',
#        'precipitation', 'new_snow', 'snow_depth', 'status', 'encounter_closed',
#        'dept', 'dept_id', 'Avg_payment', 'visit_type', 'visit_type_id',
#        'copay_paid', 'chkin_time', 'check_in-check out', 'encounter_diagnoses',
#        'next_appt', 'appt_type', 'patient_employer', 'employer_state',
#        'patient_state', 'time_with_provider', 'wait_time_for_provider',
#        'zip_code', 'pcp', 'reason_for_visit', 'roomed_time', 'employer_zip',
#        'attending_provider', 'service', 'language', 'religion', 'hosp_acct',
#        'special_needs'],
#       dtype='object')

# %% [markdown]
# # **DATA WRANGLING**

# %%
# Drop Columns
ns_df = df.drop(columns=['chkin_time', 'check_in-check out', 'next_appt', 'encounter_closed', 'time_with_provider', 'status', 
                         'wait_time_for_provider', 'roomed_time', 'hosp_acct', 'copay_paid', 'max_temp', 'mini_temp', 'departure', 'hdd', 'cdd',
                         'next_appt', 'snow_depth'])

# %%
ns_df.columns
# Out:
# Index(['mrn', 'dob', 'age', 'sex', 'phone', 'encounter_provider', 'visit_date',
#        'appt_time', 'month', 'day_of_the_week', 'holiday', 'weather_type',
#        'avg_temp', 'precipitation', 'new_snow', 'dept', 'dept_id',
#        'Avg_payment', 'visit_type', 'visit_type_id', 'encounter_diagnoses',
#        'appt_type', 'patient_employer', 'employer_state', 'patient_state',
#        'zip_code', 'pcp', 'reason_for_visit', 'employer_zip',
#        'attending_provider', 'service', 'language', 'religion',
#        'special_needs'],
#       dtype='object')

# %%
# Copying "sex" column
ns_df['sex_id'] = ns_df['sex']

# %%
# # Changing string values to integers for plotting purposes
ns_df['sex_id'].replace('Female', 1, inplace=True)
ns_df['sex_id'].replace('Male', 2, inplace=True)

# %%
# Change type
ns_df['dob'] = pd.to_datetime(ns_df['dob'])

# %%
# Change type
ns_df['visit_date'] = pd.to_datetime(ns_df['visit_date'])

# %%
# Add month column
ns_df['month'] = pd.DatetimeIndex(ns_df['visit_date']).month

# %%
# Add Year Column
ns_df['year'] = pd.DatetimeIndex(ns_df['visit_date']).year

# %%
# Change type
ns_df['mrn'] = ns_df['mrn'].astype('Int64')

# %%
# Change type
ns_df['age'] = ns_df['age'].astype('Int64')

# %%
# Change type
ns_df['dept_id'] = ns_df['dept_id'].astype('Int64')

# %%
# Change type
ns_df['visit_type_id'] = ns_df['visit_type_id'].astype('Int64')

# %%
# Change type
ns_df['sex_id'] = ns_df['sex_id'].astype('Int64')

# %%
# Change type
ns_df['year'] = ns_df['year'].astype('Int64')

# %%
# Change type
ns_df['month'] = ns_df['month'].astype('Int64')

# %%
ns_df['value_count'] = 1
ns_df
# Out:
#          mrn        dob   age     sex  ... special_needs sex_id  year value_count
# 0      10302 1965-10-10    54    Male  ...           NaN      2  2019           1
# 1       8542 1970-05-04    50  Female  ...           NaN      1  2019           1
# 2      12208 1961-10-23    58    Male  ...           NaN      2  2019           1
# 3      21117 1949-05-21    70  Female  ...           NaN      1  2019           1
# 4      18461 1948-02-24    72    Male  ...           NaN      2  2019           1
# ...      ...        ...   ...     ...  ...           ...    ...   ...         ...
# 21221  10301 1967-08-08    53  Female  ...          None      1  2020           1
# 21222  17796 1950-12-12    69  Female  ...           NaN      1  2020           1
# 21223  16786 1954-08-02    66  Female  ...           NaN      1  2020           1
# 21224   3993 1987-01-10    33  Female  ...           NaN      1  2020           1
# 21225   <NA>        NaT  <NA>     NaN  ...           NaN   <NA>  <NA>           1
#
# [21226 rows x 37 columns]

# %%
ns_df.drop(ns_df.index[21225])
# Out:
#          mrn        dob  age     sex  ... special_needs sex_id  year value_count
# 0      10302 1965-10-10   54    Male  ...           NaN      2  2019           1
# 1       8542 1970-05-04   50  Female  ...           NaN      1  2019           1
# 2      12208 1961-10-23   58    Male  ...           NaN      2  2019           1
# 3      21117 1949-05-21   70  Female  ...           NaN      1  2019           1
# 4      18461 1948-02-24   72    Male  ...           NaN      2  2019           1
# ...      ...        ...  ...     ...  ...           ...    ...   ...         ...
# 21220   9838 1967-11-25   52  Female  ...           NaN      1  2020           1
# 21221  10301 1967-08-08   53  Female  ...          None      1  2020           1
# 21222  17796 1950-12-12   69  Female  ...           NaN      1  2020           1
# 21223  16786 1954-08-02   66  Female  ...           NaN      1  2020           1
# 21224   3993 1987-01-10   33  Female  ...           NaN      1  2020           1
#
# [21225 rows x 37 columns]

# %%
ns_df["encounter_diagnoses"].fillna("Not Specified", inplace = True)

# %%
ns_df["patient_employer"].fillna("Not Specified", inplace = True)

# %%
ns_df["employer_state"].fillna("Not Specified", inplace = True)

# %%
ns_df["reason_for_visit"].fillna("Not Specified", inplace = True)

# %%
ns_df["attending_provider"].fillna("Not Specified", inplace = True)

# %%
ns_df["service"].fillna("Not Specified", inplace = True)

# %%
ns_df["language"].fillna("Not Specified", inplace = True)

# %%
ns_df["special_needs"].fillna("Not Specified", inplace = True)

# %%
ns_df.fillna(0)
# Out:
#          mrn                  dob  age  ... sex_id  year value_count
# 0      10302  1965-10-10 00:00:00   54  ...      2  2019           1
# 1       8542  1970-05-04 00:00:00   50  ...      1  2019           1
# 2      12208  1961-10-23 00:00:00   58  ...      2  2019           1
# 3      21117  1949-05-21 00:00:00   70  ...      1  2019           1
# 4      18461  1948-02-24 00:00:00   72  ...      2  2019           1
# ...      ...                  ...  ...  ...    ...   ...         ...
# 21221  10301  1967-08-08 00:00:00   53  ...      1  2020           1
# 21222  17796  1950-12-12 00:00:00   69  ...      1  2020           1
# 21223  16786  1954-08-02 00:00:00   66  ...      1  2020           1
# 21224   3993  1987-01-10 00:00:00   33  ...      1  2020           1
# 21225      0                    0    0  ...      0     0           1
#
# [21226 rows x 37 columns]

# %%
ns_df.head()
# Out:
#      mrn        dob  age     sex  ...  special_needs sex_id  year value_count
# 0  10302 1965-10-10   54    Male  ...  Not Specified      2  2019           1
# 1   8542 1970-05-04   50  Female  ...  Not Specified      1  2019           1
# 2  12208 1961-10-23   58    Male  ...  Not Specified      2  2019           1
# 3  21117 1949-05-21   70  Female  ...  Not Specified      1  2019           1
# 4  18461 1948-02-24   72    Male  ...  Not Specified      2  2019           1
#
# [5 rows x 37 columns]

# %%
ns_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21226 entries, 0 to 21225
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   mrn                  21225 non-null  Int64
#  1   dob                  21225 non-null  datetime64[ns]
#  2   age                  21225 non-null  Int64
#  3   sex                  21225 non-null  object
#  4   phone                21022 non-null  object
#  5   encounter_provider   21225 non-null  object
#  6   visit_date           21225 non-null  datetime64[ns]
#  7   appt_time            21225 non-null  object
#  8   month                21225 non-null  Int64
#  9   day_of_the_week      21225 non-null  object
#  10  holiday              21225 non-null  object
#  11  weather_type         21225 non-null  object
#  12  avg_temp             21225 non-null  float64
#  13  precipitation        21225 non-null  float64
#  14  new_snow             21225 non-null  float64
#  15  dept                 21225 non-null  object
#  16  dept_id              21225 non-null  Int64
#  17  Avg_payment          21225 non-null  float64
#  18  visit_type           21225 non-null  object
#  19  visit_type_id        21225 non-null  Int64
#  20  encounter_diagnoses  21226 non-null  object
#  21  appt_type            21225 non-null  object
#  22  patient_employer     21226 non-null  object
#  23  employer_state       21226 non-null  object
#  24  patient_state        21225 non-null  object
#  25  zip_code             21225 non-null  object
#  26  pcp                  19766 non-null  object
#  27  reason_for_visit     21226 non-null  object
#  28  employer_zip         21225 non-null  object
#  29  attending_provider   21226 non-null  object
#  30  service              21226 non-null  object
#  31  language             21226 non-null  object
#  32  religion             21146 non-null  object
#  33  special_needs        21226 non-null  object
#  34  sex_id               21225 non-null  Int64
#  35  year                 21225 non-null  Int64
#  36  value_count          21226 non-null  int64
# dtypes: Int64(7), datetime64[ns](2), float64(4), int64(1), object(23)
# memory usage: 6.1+ MB

# %%
# Re-arranged columns
ns_df = ns_df[['mrn', 'dob', 'age', 'sex', 'sex_id', 'phone', 'encounter_provider', 'visit_date',
       'appt_time', 'month', 'year', 'day_of_the_week', 'holiday', 'weather_type',
       'avg_temp', 'precipitation', 'new_snow', 'dept', 'dept_id',
       'Avg_payment', 'visit_type', 'visit_type_id', 'encounter_diagnoses',
       'appt_type', 'patient_employer', 'employer_state', 'patient_state',
       'zip_code', 'pcp', 'reason_for_visit', 'employer_zip',
       'attending_provider', 'service', 'language', 'religion','special_needs']]

# %% [markdown]
# # EDA (Exploratoty Data Analysis)

# %%
ns_year = ns_df['year']
ns_month = ns_df['month']
ns_sexid = ns_df['sex_id']
ns_age = ns_df['age']
ns_age = ns_df['age'].value_counts()
ns_deptid = ns_df['dept_id']
ns_mrn = ns_df['mrn']

# %%
df1.plot(kind='bar')

# %%
df2.plot(kind='line')

# %%
fig, ax = plt.subplots(figsize=(15,7))
ns_df.groupby(['age','sex']).count()['month'].unstack().plot(ax=ax)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ns_df['age'].plot.hist()

# %% [markdown]
# # Conclusion

# %% [markdown]
# # References:
#
# * https://github.com/nytimes/covid-19-data
# * https://pandas.pydata.org/
# * https://plotly.com/python/range-slider/
# * https://plotly.com/python/
# * https://seaborn.pydata.org/
# * https://matplotlib.org/
